# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data = pd.read_csv('data.csv', na_values=[ ".."], index_col=['Country Name', 'Series Name'])
data
# Out:
#                                                                   1960  1961  \
# Country Name  Series Name
# Afghanistan   Government expenditure on education, total (% o...   NaN   NaN
# Albania       Government expenditure on education, total (% o...   NaN   NaN
# Algeria       Government expenditure on education, total (% o...   NaN   NaN
# Andorra       Government expenditure on education, total (% o...   NaN   NaN
# Angola        Government expenditure on education, total (% o...   NaN   NaN
# ...                                                                ...   ...
# Europe        Pupil-teacher ratio, primary                         NaN   NaN
# South America Pupil-teacher ratio, primary                         NaN   NaN
# North America Pupil-teacher ratio, primary                         NaN   NaN
# Asia          Pupil-teacher ratio, primary                         NaN   NaN
# Africa        Pupil-teacher ratio, primary                         NaN   NaN
#
#                                                                   1962  1963  \
# Country Name  Series Name
# Afghanistan   Government expenditure on education, total (% o...   NaN   NaN
# Albania       Government expenditure on education, total (% o...   NaN   NaN
# Algeria       Government expenditure on education, total (% o...   NaN   NaN
# Andorra       Government expenditure on education, total (% o...   NaN   NaN
# Angola        Government expenditure on education, total (% o...   NaN   NaN
# ...                                                                ...   ...
# Europe        Pupil-teacher ratio, primary                         NaN   NaN
# South America Pupil-teacher ratio, primary                         NaN   NaN
# North America Pupil-teacher ratio, primary                         NaN   NaN
# Asia          Pupil-teacher ratio, primary                         NaN   NaN
# Africa        Pupil-teacher ratio, primary                         NaN   NaN
#
#                                                                   1964  1965  \
# Country Name  Series Name
# Afghanistan   Government expenditure on education, total (% o...   NaN   NaN
# Albania       Government expenditure on education, total (% o...   NaN   NaN
# Algeria       Government expenditure on education, total (% o...   NaN   NaN
# Andorra       Government expenditure on education, total (% o...   NaN   NaN
# Angola        Government expenditure on education, total (% o...   NaN   NaN
# ...                                                                ...   ...
# Europe        Pupil-teacher ratio, primary                         NaN   NaN
# South America Pupil-teacher ratio, primary                         NaN   NaN
# North America Pupil-teacher ratio, primary                         NaN   NaN
# Asia          Pupil-teacher ratio, primary                         NaN   NaN
# Africa        Pupil-teacher ratio, primary                         NaN   NaN
#
#                                                                   1966  1967  \
# Country Name  Series Name
# Afghanistan   Government expenditure on education, total (% o...   NaN   NaN
# Albania       Government expenditure on education, total (% o...   NaN   NaN
# Algeria       Government expenditure on education, total (% o...   NaN   NaN
# Andorra       Government expenditure on education, total (% o...   NaN   NaN
# Angola        Government expenditure on education, total (% o...   NaN   NaN
# ...                                                                ...   ...
# Europe        Pupil-teacher ratio, primary                         NaN   NaN
# South America Pupil-teacher ratio, primary                         NaN   NaN
# North America Pupil-teacher ratio, primary                         NaN   NaN
# Asia          Pupil-teacher ratio, primary                         NaN   NaN
# Africa        Pupil-teacher ratio, primary                         NaN   NaN
#
#                                                                   1968  1969  \
# Country Name  Series Name
# Afghanistan   Government expenditure on education, total (% o...   NaN   NaN
# Albania       Government expenditure on education, total (% o...   NaN   NaN
# Algeria       Government expenditure on education, total (% o...   NaN   NaN
# Andorra       Government expenditure on education, total (% o...   NaN   NaN
# Angola        Government expenditure on education, total (% o...   NaN   NaN
# ...                                                                ...   ...
# Europe        Pupil-teacher ratio, primary                         NaN   NaN
# South America Pupil-teacher ratio, primary                         NaN   NaN
# North America Pupil-teacher ratio, primary                         NaN   NaN
# Asia          Pupil-teacher ratio, primary                         NaN   NaN
# Africa        Pupil-teacher ratio, primary                         NaN   NaN
#
#                                                                   ...  \
# Country Name  Series Name                                         ...
# Afghanistan   Government expenditure on education, total (% o...  ...
# Albania       Government expenditure on education, total (% o...  ...
# Algeria       Government expenditure on education, total (% o...  ...
# Andorra       Government expenditure on education, total (% o...  ...
# Angola        Government expenditure on education, total (% o...  ...
# ...                                                               ...
# Europe        Pupil-teacher ratio, primary                        ...
# South America Pupil-teacher ratio, primary                        ...
# North America Pupil-teacher ratio, primary                        ...
# Asia          Pupil-teacher ratio, primary                        ...
# Africa        Pupil-teacher ratio, primary                        ...
#
#                                                                        2013  \
# Country Name  Series Name
# Afghanistan   Government expenditure on education, total (% o...   7.132068
# Albania       Government expenditure on education, total (% o...  11.580032
# Algeria       Government expenditure on education, total (% o...  17.646034
# Andorra       Government expenditure on education, total (% o...   5.672310
# Angola        Government expenditure on education, total (% o...   8.826971
# ...                                                                     ...
# Europe        Pupil-teacher ratio, primary                        14.961400
# South America Pupil-teacher ratio, primary                        22.247360
# North America Pupil-teacher ratio, primary                        14.657940
# Asia          Pupil-teacher ratio, primary                        33.488070
# Africa        Pupil-teacher ratio, primary                        38.795570
#
#                                                                        2014  \
# Country Name  Series Name
# Afghanistan   Government expenditure on education, total (% o...   7.964570
# Albania       Government expenditure on education, total (% o...  10.988461
# Algeria       Government expenditure on education, total (% o...  16.469202
# Andorra       Government expenditure on education, total (% o...  12.554050
# Angola        Government expenditure on education, total (% o...   7.130000
# ...                                                                     ...
# Europe        Pupil-teacher ratio, primary                        14.926890
# South America Pupil-teacher ratio, primary                        21.963390
# North America Pupil-teacher ratio, primary                        14.739380
# Asia          Pupil-teacher ratio, primary                        32.788000
# Africa        Pupil-teacher ratio, primary                        37.982050
#
#                                                                        2015  \
# Country Name  Series Name
# Afghanistan   Government expenditure on education, total (% o...   7.284905
# Albania       Government expenditure on education, total (% o...  10.441024
# Algeria       Government expenditure on education, total (% o...  15.202961
# Andorra       Government expenditure on education, total (% o...  10.392500
# Angola        Government expenditure on education, total (% o...   8.918777
# ...                                                                     ...
# Europe        Pupil-teacher ratio, primary                        14.751720
# South America Pupil-teacher ratio, primary                        21.721390
# North America Pupil-teacher ratio, primary                        14.668270
# Asia          Pupil-teacher ratio, primary                        32.721400
# Africa        Pupil-teacher ratio, primary                        37.505960
#
#                                                                        2016  \
# Country Name  Series Name
# Afghanistan   Government expenditure on education, total (% o...   8.260236
# Albania       Government expenditure on education, total (% o...  10.829787
# Algeria       Government expenditure on education, total (% o...  16.111044
# Andorra       Government expenditure on education, total (% o...   7.215240
# Angola        Government expenditure on education, total (% o...   6.550974
# ...                                                                     ...
# Europe        Pupil-teacher ratio, primary                        14.696030
# South America Pupil-teacher ratio, primary                        21.556420
# North America Pupil-teacher ratio, primary                        14.545600
# Asia          Pupil-teacher ratio, primary                        35.554190
# Africa        Pupil-teacher ratio, primary                        37.505990
#
#                                                                        2017  \
# Country Name  Series Name
# Afghanistan   Government expenditure on education, total (% o...   8.202472
# Albania       Government expenditure on education, total (% o...  10.570190
# Algeria       Government expenditure on education, total (% o...  17.556072
# Andorra       Government expenditure on education, total (% o...   8.978000
# Angola        Government expenditure on education, total (% o...   6.763777
# ...                                                                     ...
# Europe        Pupil-teacher ratio, primary                        14.856810
# South America Pupil-teacher ratio, primary                        21.340330
# North America Pupil-teacher ratio, primary                        14.427050
# Asia          Pupil-teacher ratio, primary                        33.248490
# Africa        Pupil-teacher ratio, primary                        37.368450
#
#                                                                        2018  \
# Country Name  Series Name
# Afghanistan   Government expenditure on education, total (% o...        NaN
# Albania       Government expenditure on education, total (% o...  10.970696
# Algeria       Government expenditure on education, total (% o...  14.949346
# Andorra       Government expenditure on education, total (% o...  13.258810
# Angola        Government expenditure on education, total (% o...   5.410232
# ...                                                                     ...
# Europe        Pupil-teacher ratio, primary                        14.869650
# South America Pupil-teacher ratio, primary                        21.302150
# North America Pupil-teacher ratio, primary                        14.425240
# Asia          Pupil-teacher ratio, primary                        33.246690
# Africa        Pupil-teacher ratio, primary                        37.361940
#
#                                                                        2019  \
# Country Name  Series Name
# Afghanistan   Government expenditure on education, total (% o...        NaN
# Albania       Government expenditure on education, total (% o...  11.400180
# Algeria       Government expenditure on education, total (% o...  14.463093
# Andorra       Government expenditure on education, total (% o...  10.398080
# Angola        Government expenditure on education, total (% o...   6.045356
# ...                                                                     ...
# Europe        Pupil-teacher ratio, primary                              NaN
# South America Pupil-teacher ratio, primary                              NaN
# North America Pupil-teacher ratio, primary                              NaN
# Asia          Pupil-teacher ratio, primary                              NaN
# Africa        Pupil-teacher ratio, primary                              NaN
#
#                                                                        2020  \
# Country Name  Series Name
# Afghanistan   Government expenditure on education, total (% o...        NaN
# Albania       Government expenditure on education, total (% o...  10.134383
# Algeria       Government expenditure on education, total (% o...  16.549171
# Andorra       Government expenditure on education, total (% o...   6.938821
# Angola        Government expenditure on education, total (% o...   6.467227
# ...                                                                     ...
# Europe        Pupil-teacher ratio, primary                              NaN
# South America Pupil-teacher ratio, primary                              NaN
# North America Pupil-teacher ratio, primary                              NaN
# Asia          Pupil-teacher ratio, primary                              NaN
# Africa        Pupil-teacher ratio, primary                              NaN
#
#                                                                        2021  \
# Country Name  Series Name
# Afghanistan   Government expenditure on education, total (% o...        NaN
# Albania       Government expenditure on education, total (% o...   9.833778
# Algeria       Government expenditure on education, total (% o...  16.050697
# Andorra       Government expenditure on education, total (% o...   6.350282
# Angola        Government expenditure on education, total (% o...   6.919610
# ...                                                                     ...
# Europe        Pupil-teacher ratio, primary                              NaN
# South America Pupil-teacher ratio, primary                              NaN
# North America Pupil-teacher ratio, primary                              NaN
# Asia          Pupil-teacher ratio, primary                              NaN
# Africa        Pupil-teacher ratio, primary                              NaN
#
#                                                                        2022
# Country Name  Series Name
# Afghanistan   Government expenditure on education, total (% o...        NaN
# Albania       Government expenditure on education, total (% o...        NaN
# Algeria       Government expenditure on education, total (% o...  13.101506
# Andorra       Government expenditure on education, total (% o...   6.605960
# Angola        Government expenditure on education, total (% o...   6.640472
# ...                                                                     ...
# Europe        Pupil-teacher ratio, primary                              NaN
# South America Pupil-teacher ratio, primary                              NaN
# North America Pupil-teacher ratio, primary                              NaN
# Asia          Pupil-teacher ratio, primary                              NaN
# Africa        Pupil-teacher ratio, primary                              NaN
#
# [1964 rows x 63 columns]

# %%
pt_data = data.pivot_table(data,  index=['Country Name', 'Series Name'])

# %%
#data.dropna(axis='rows', thresh=10)

# %%
df = data['2022']
#restting the index
df1 = df.reset_index('Series Name')
# Filter data for the year 2022 and the specified series name
plot1 = df1[(df1['Series Name'] == 'Government expenditure on education, total (% of government expenditure)')]

# Sort data by the '2022' column in descending order and select the top 10 rows
plot1 = plot1.sort_values(by='2022', ascending=False).head(10)
plot1 = plot1.sort_values(by='2022')
print(plot1)
# Out:
#                                                           Series Name  \
# Country Name
# Malaysia            Government expenditure on education, total (% ...
# Burundi             Government expenditure on education, total (% ...
# Puerto Rico         Government expenditure on education, total (% ...
# Uzbekistan          Government expenditure on education, total (% ...
# Burkina Faso        Government expenditure on education, total (% ...
# Senegal             Government expenditure on education, total (% ...
# Dominican Republic  Government expenditure on education, total (% ...
# Ethiopia            Government expenditure on education, total (% ...
# Morocco             Government expenditure on education, total (% ...
# Namibia             Government expenditure on education, total (% ...
#
#                          2022
# Country Name
# Malaysia            20.149679
# Burundi             20.637083
# Puerto Rico         21.243938
# Uzbekistan          21.851019
# Burkina Faso        21.958097
# Senegal             22.165987
# Dominican Republic  22.444557
# Ethiopia            23.006403
# Morocco             23.865665
# Namibia             24.706921

# %%
# Assuming 'Country' is a column in your DataFrame
selected_countries = ['Europe', 'South America', 'North America','Asia','Africa','Australia']

df2= data.ffill( axis=1)

# Filter data for the year 2022 and the specified series name
df2 = df2['2022']
# Reset the index
df2 = df2.reset_index()
# Use boolean indexing to select specific countries
df2 = df2[df2['Country Name'].isin(selected_countries)]
plot2 = df2.set_index('Country Name')
plot2 = plot2[(plot2['Series Name'] == 'Pupil-teacher ratio, primary')]
# Display the resulting DataFrame
print(plot2)
# Out:
#                                 Series Name      2022
# Country Name
# Australia      Pupil-teacher ratio, primary  17.87578
# Europe         Pupil-teacher ratio, primary  14.86965
# South America  Pupil-teacher ratio, primary  21.30215
# North America  Pupil-teacher ratio, primary  14.42524
# Asia           Pupil-teacher ratio, primary  33.24669
# Africa         Pupil-teacher ratio, primary  37.36194

# %%
df3= data.reset_index('Series Name')
# Filter data for the year 2022 and the specified series name
plot3 = df3[(df3['Series Name'] == 'Primary education, pupils')]
plot3 = plot3.sort_values(by='2022', ascending=False).head(4)
plot3 = plot3.dropna(axis='columns', how='all')
plot3 = plot3.bfill( axis=1)
print(plot3)
# Out:
#                             Series Name         1970         1971  \
# Country Name
# India         Primary education, pupils   57045440.0   57045440.0
# China         Primary education, pupils  100668000.0  105280000.0
# Indonesia     Primary education, pupils   14870220.0   15519557.0
# Bangladesh    Primary education, pupils    5283787.0    5040003.0
#
#                      1972         1973         1974         1975         1976  \
# Country Name
# India          58818644.0   62400628.0   63125100.0   64855640.0   65660024.0
# China         112112000.0  125492000.0  135704000.0  144814000.0  150940992.0
# Indonesia      16140125.0   16643900.0   16892010.0   17776616.0   18779944.0
# Bangladesh      6416954.0    7793907.0    7747559.0    8349834.0    8674004.0
#
#                      1977         1978  ...         2013         2014  \
# Country Name                            ...
# India          69060728.0   67360992.0  ...  132043360.0  127827864.0
# China         150055008.0  146176000.0  ...   98870816.0   95107120.0
# Indonesia      19783270.0   22024820.0  ...   30109356.0   29838440.0
# Bangladesh      8227950.0    8219313.0  ...   17195384.0   17195384.0
#
#                      2015         2016         2017         2018         2019  \
# Country Name
# India         127827864.0  126563424.0  123807888.0  120044808.0  120044808.0
# China          95958040.0   98189336.0  100321024.0  101872976.0  104325248.0
# Indonesia      29699772.0   29450356.0   29351816.0   29425748.0   29120792.0
# Bangladesh     17195384.0   17195384.0   17195384.0   17338100.0   17603840.0
#
#                      2020         2021         2022
# Country Name
# India         121700128.0  122027752.0  131348080.0
# China         106250528.0  107730040.0  108019744.0
# Indonesia      29329968.0   29241826.0   28829724.0
# Bangladesh     17603840.0   16964968.0   17162364.0
#
# [4 rows x 54 columns]

# %%
df4= data.ffill( axis=1)

# Filter data for the year 2022 and the specified series name
df4 = df4['2022']
df4 = df4.reset_index('Series Name')

plot4 = df4[(df4['Series Name'] == 'Literacy rate, adult total (% of people ages 15 and above)')]

# Sort data by the '2022' column in descending order and select the top 10 rows
plot4 = plot4.sort_values(by='2022', ascending=False).head(7)
plot4 = plot4.sort_values(by='2022')

print(plot4)
# Out:
#                                                     Series Name        2022
# Country Name
# Estonia       Literacy rate, adult total (% of people ages 1...   99.870003
# Belarus       Literacy rate, adult total (% of people ages 1...   99.874001
# Latvia        Literacy rate, adult total (% of people ages 1...   99.889999
# Russia        Literacy rate, adult total (% of people ages 1...   99.927773
# Korea         Literacy rate, adult total (% of people ages 1...   99.998192
# Uzbekistan    Literacy rate, adult total (% of people ages 1...   99.999977
# Ukraine       Literacy rate, adult total (% of people ages 1...  100.000000

# %%
#Create a figure and subplots
fig, ax = plt.subplots(3, 2, figsize=(26, 18), gridspec_kw={'width_ratios': [1, 1],'height_ratios': [1, 1,1]})
fig.suptitle('''World Education Report 2022
      Name: Mansoor Kashif
        ID: 22085607''',
             fontsize=22,
             fontweight='bold')

# Plotting the data for the top 10 countries
ax[0,0].barh(plot1.index, plot1['2022'], color=['blue','yellow'])
# Setting and title
ax[0,0].set_title('Expenditure on education (% of government expenditure ): 2022',fontsize=22,fontweight='bold' ,color='red')
ax[0,0].spines[['top', 'right', 'bottom','left']].set_visible(False)
ax[0,0].set_xlim(left=18, right=25)
ax[0,0].tick_params(labelsize=18)
ax[0,0].set_xticks([])
for i, v in enumerate(plot1.values[:, 1]):
    ax[0,0].text(v, i, '{:.2f}'.format(v), ha='left', va='center',
             fontsize=16)


wedges,_, autotexts = ax[0,1].pie(plot2['2022'], explode = (0, 0, 0, 0,0,0.1),autopct='%1.1f%%',shadow=True, startangle=90)
# Set legend
ax[0,1].legend(wedges, plot2.index, loc="center left", bbox_to_anchor=(-0.7, 0.5),fontsize=18)
ax[0,1].set_title('Pupil-teacher ratio : 2022', fontsize=19,fontweight='bold' ,color='red')
# Set label font size
for autotext in autotexts:
    autotext.set_fontsize(16)


# Plotting the data for the top 10 countries
ax[1,0].plot(plot3.iloc[:, 1:].T,linewidth=5)
years = plot3.T.index[1::10]  # Select every 10th year
ax[1,0].set_xticks(years)
ax[1,0].set_xticklabels(years)
ax[1,0].set_title('Countries with Highest Primary Education Pupils Growth', fontsize=22,fontweight='bold' ,color='red')
ax[1,0].spines[['top','right']].set_visible(False)
ax[1,0].tick_params(labelsize=18)
ax[1,0].set_ylabel('No. of pupils',fontsize=18)
ax[1,0].grid(True, linestyle='--', linewidth=0.6, color='gray', alpha=0.9)
ax[1,0].legend(labels=plot3.index, loc='center right', frameon=False,
           ncols=2, fontsize=18)  

# Plotting the data for the top 10 countries
ax[1,1].barh(plot4.index, plot4['2022'], color=['mediumseagreen','orange'])
# Setting and title
ax[1,1].set_title('Countries with Highest Literacy Rate : 2022',fontsize=22,fontweight='bold' ,color='red')
ax[1,1].spines[['top', 'right', 'bottom','left']].set_visible(False)
ax[1,1].set_xlim(left=99.5, right=100.1)
ax[1,1].tick_params(labelsize=18)
ax[1,1].set_xticks([])
for i, v in enumerate(plot4.values[:, 1]):
    ax[1,1].text(v, i, '{:.2f}'.format(v), ha='left', va='center',
             fontsize=16)

# Adding explaination text visualization
text = """This infographics analyse the status of global educational statistics in 2022. 
               - In 2022, Namibia spend 24.71% of its Government expenditures on Education.
               - North America has 10.4 pupil-teacher ratio which means that there are 10 pupils for 1 teacher while on the other
                 hand Africa has almost 27 pupil per teacher.
               - Ukraine, Uzbekistan and Korea are only three countries in the World with 100% literacy rate in 2022.
               - Primary education pupil line chart shows that China No. of pupil drops two times after 1977.
               - The reason for this decline is China One-child policy implemented in 1979."""

combined_subplot = ax[2, :].flatten()
combined_subplot[0].text(-0.1, 0.5, text, ha='left', va='center', fontsize=24, color='black')
for ax in combined_subplot:
    ax.tick_params(length=0, width=0)
    ax.set_facecolor('none')
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    ax.spines[['top', 'bottom', 'left', 'right']].set_visible(False)


plt.savefig('22085607.png', dpi=300)
plt.show()
